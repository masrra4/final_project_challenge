# %%
import pandas as pd

# %%
df=pd.read_csv('C:\\Users\\masrra\\Desktop\\TA_restaurants_curated.csv',na_values='[[], []]')
df
# Out:
#         Unnamed: 0                          Name       City  \
# 0                0    Martine of Martine's Table  Amsterdam
# 1                1           De Silveren Spiegel  Amsterdam
# 2                2                       La Rive  Amsterdam
# 3                3                      Vinkeles  Amsterdam
# 4                4     Librije's Zusje Amsterdam  Amsterdam
# ...            ...                           ...        ...
# 125522        1662  Konrad Kaffee- & Cocktailbar     Zurich
# 125523        1663     Blueberry American Bakery     Zurich
# 125524        1664            Restaurant Bahnhof     Zurich
# 125525        1665                    Yoyo Pizza     Zurich
# 125526        1666                         dieci     Zurich
#
#                                             Cuisine Style  Ranking  Rating  \
# 0                         ['French', 'Dutch', 'European']      1.0     5.0
# 1       ['Dutch', 'European', 'Vegetarian Friendly', '...      2.0     4.5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125527 entries, 0 to 125526
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         125527 non-null  int64
#  1   Name               125527 non-null  object
#  2   City               125527 non-null  object
#  3   Cuisine Style      94176 non-null   object
#  4   Ranking            115876 non-null  float64
#  5   Rating             115897 non-null  float64
#  6   Price Range        77672 non-null   object
#  7   Number of Reviews  108183 non-null  float64
#  8   Reviews            96817 non-null   object
#  9   URL_TA             125527 non-null  object
#  10  ID_TA              125527 non-null  object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 10.5+ MB

# %%
df.nunique()
# Out:
# Unnamed: 0            18212
# Name                 111927
# City                     31
# Cuisine Style         20971
# Ranking               16442
# Rating                   10
# Price Range               3
# Number of Reviews      2079
# Reviews               96695
# URL_TA               125326
# ID_TA                125326
# dtype: int64

# %%
df[df['Cuisine Style']=='NaN']
df1=df.dropna()
df1
# Out:
#         Unnamed: 0                        Name       City  \
# 0                0  Martine of Martine's Table  Amsterdam
# 1                1         De Silveren Spiegel  Amsterdam
# 2                2                     La Rive  Amsterdam
# 3                3                    Vinkeles  Amsterdam
# 4                4   Librije's Zusje Amsterdam  Amsterdam
# ...            ...                         ...        ...
# 125423        1563                  Taj Palace     Zurich
# 125434        1574                       Forum     Zurich
# 125435        1575                      PurPur     Zurich
# 125438        1578                        Jade     Zurich
# 125445        1585       Ristorante La Taverna     Zurich
#
#                                             Cuisine Style  Ranking  Rating  \
# 0                         ['French', 'Dutch', 'European']      1.0     5.0
# 1       ['Dutch', 'European', 'Vegetarian Friendly', '...      2.0     4.5
# ...

# %%
d=df1.isnull()
d
# Out:
#         Unnamed: 0   Name   City  Cuisine Style  Ranking  Rating  Price Range  \
# 0            False  False  False          False    False   False        False
# 1            False  False  False          False    False   False        False
# 2            False  False  False          False    False   False        False
# 3            False  False  False          False    False   False        False
# 4            False  False  False          False    False   False        False
# ...            ...    ...    ...            ...      ...     ...          ...
# 125423       False  False  False          False    False   False        False
# 125434       False  False  False          False    False   False        False
# 125435       False  False  False          False    False   False        False
# 125438       False  False  False          False    False   False        False
# 125445       False  False  False          False    False   False        False
#
# ...

# %%
#percentage of missingness
d.mean()*100
# Out:
# Unnamed: 0           0.0
# Name                 0.0
# City                 0.0
# Cuisine Style        0.0
# Ranking              0.0
# Rating               0.0
# Price Range          0.0
# Number of Reviews    0.0
# Reviews              0.0
# URL_TA               0.0
# ID_TA                0.0
# dtype: float64

# %%
# !pip install missingno

# %%
import missingno as msno
msno.bar(d)
# Out:
# <AxesSubplot:>

# %%
msno.matrix(d)
# Out:
# <AxesSubplot:>

# %%
del df1["Unnamed: 0"]
del df1["ID_TA"]
del df1["URL_TA"]
del df1["Ranking"]

df1
# Out:
#                               Name       City  \
# 0       Martine of Martine's Table  Amsterdam
# 1              De Silveren Spiegel  Amsterdam
# 2                          La Rive  Amsterdam
# 3                         Vinkeles  Amsterdam
# 4        Librije's Zusje Amsterdam  Amsterdam
# ...                            ...        ...
# 125423                  Taj Palace     Zurich
# 125434                       Forum     Zurich
# 125435                      PurPur     Zurich
# 125438                        Jade     Zurich
# 125445       Ristorante La Taverna     Zurich
#
#                                             Cuisine Style  Rating Price Range  \
# 0                         ['French', 'Dutch', 'European']     5.0    $$ - $$$
# 1       ['Dutch', 'European', 'Vegetarian Friendly', '...     4.5        $$$$
# 2       ['Mediterranean', 'French', 'International', '...     4.5        $$$$
# 3       ['French', 'European', 'International', 'Conte...     5.0        $$$$
# ...

# %%
import numpy as np
reviews_unique=df1.Reviews.unique()
np.sort(reviews_unique)
# Out:
# array(['[["\'Good place for lunch", \'Relaxed\'], [\'02/25/2017\', \'01/10/2015\']]',
#        '[["\'Great Little Trendy Pub!\'", \'Great Fun!\'], [\'11/23/2016\', \'09/05/2016\']]',
#        '[["\'In the Court of the Crimson King\' played...", \'Great Menu del Dia\'], [\'07/15/2017\', \'06/06/2016\']]',
#        ...,
#        "[['😀Excellent food ,good service 😀', 'Awesome Indian and Turkish'], ['06/09/2016', '05/23/2016']]",
#        '[[\'😊\', "Weekok it with but it\'s OK."], [\'01/22/2016\', \'03/11/2015\']]',
#        "[[nan, 'Good food with decent service'], ['11/21/2017', '07/21/2017']]"],
#       dtype=object)

# %%
df1.nunique()
# Out:
# Name                 65088
# City                    31
# Cuisine Style        18573
# Rating                   9
# Price Range              3
# Number of Reviews     2073
# Reviews              71098
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 71181 entries, 0 to 125445
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               71181 non-null  object
#  1   City               71181 non-null  object
#  2   Cuisine Style      71181 non-null  object
#  3   Rating             71181 non-null  float64
#  4   Price Range        71181 non-null  object
#  5   Number of Reviews  71181 non-null  float64
#  6   Reviews            71181 non-null  object
# dtypes: float64(2), object(5)
# memory usage: 4.3+ MB

# %%
df1.to_csv('restaurantt data.csv')
